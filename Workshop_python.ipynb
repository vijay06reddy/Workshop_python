# %% [markdown]
# <a href="https://colab.research.google.com/github/vijay06reddy/Workshop_python/blob/main/Workshop_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Loop Control Statement

# %%
i = 1 #initialization
while(i<=5):  #while(condition)
  print("Hello, SRU")   #code that you want to repeat
  i=i+1   #increment variable value
# Out:
# Hello, SRU
# Hello, SRU
# Hello, SRU
# Hello, SRU
# Hello, SRU

# %%
num=input("Enter the number")
num=int(num)
i = 0   #initialization
while (i<=9):
  print(f"{num} * {i+1} = {num*(i+1)}")
  i = i+1
# Out:
# Enter the number12
# 12 * 1 = 12
# 12 * 2 = 24
# 12 * 3 = 36
# 12 * 4 = 48
# 12 * 5 = 60
# 12 * 6 = 72
# 12 * 7 = 84
# 12 * 8 = 96
# 12 * 9 = 108
# 12 * 10 = 120

# %% [markdown]
# Break Statement

# %%
num=input("Enter the number")
num=int(num)
i = 1  #initialization
while (i<=10):
  print(f"{num} * {i} = {num*(i)}")
  if(i==5):
    break     #break statement
  i = i+1
# Out:
# Enter the number12
# 12 * 1 = 12
# 12 * 2 = 24
# 12 * 3 = 36
# 12 * 4 = 48
# 12 * 5 = 60

# %%
List_of_books=["Python", "Java", "C", "C++"]
book=input("Enter book you want in library")
book_no=0 #start from index 0
while(book_no < len(List_of_books)):    #Loop condition corrected to avoid out of bounds access
  if(book==List_of_books[book_no]):
    print("Yes, book available")
    break
  book_no=book_no+1
# Out:
# Enter bopk you want in libraryC
# Yes, book available

# %% [markdown]
# While-Else Statement

# %%
List_of_books=["Python", "Java", "C", "C++"]
book=input("Enter book you want in library")
book_no=0 #start from index 0
while(book_no < len(List_of_books)):    #Loop condition corrected to avoid out of bounds access
  if(book==List_of_books[book_no]):
    print("Yes, book available")
    break
  book_no=book_no+1
else:
    print("book not available")
# Out:
# Enter book you want in libraryR
# book not available

# %% [markdown]
# Nested While loop

# %% [markdown]
# Print first 2-5 Tables

# %%
i=2
while(i<=5):
  print(f"{i} table")
  j=1
  while(j<=10):
    print(f"{i}*{j} = {i*j}")
    j=j+1
  i=i+1
# Out:
# 2 table
# 2*1 = 2
# 2*2 = 4
# 2*3 = 6
# 2*4 = 8
# 2*5 = 10
# 2*6 = 12
# 2*7 = 14
# 2*8 = 16
# 2*9 = 18
# 2*10 = 20
# 3 table
# 3*1 = 3
# 3*2 = 6
# 3*3 = 9
# 3*4 = 12
# 3*5 = 15
# 3*6 = 18
# 3*7 = 21
# 3*8 = 24
# 3*9 = 27
# 3*10 = 30
# 4 table
# 4*1 = 4
# 4*2 = 8
# 4*3 = 12
# 4*4 = 16
# 4*5 = 20
# 4*6 = 24
# 4*7 = 28
# 4*8 = 32
# 4*9 = 36
# 4*10 = 40
# 5 table
# 5*1 = 5
# 5*2 = 10
# 5*3 = 15
# 5*4 = 20
# 5*5 = 25
# 5*6 = 30
# 5*7 = 35
# 5*8 = 40
# 5*9 = 45
# 5*10 = 50
